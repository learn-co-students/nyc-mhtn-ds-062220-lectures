# %% [markdown]
# # Webscraping with BeautifulSoup
#
# _May 19, 2020_
#
# #### Agenda today:
#
# - Learn about the web: components, elements
# - Webscrape use beautiful soup:
#     - Github sample website
#     - Daily weather report website

# %% [markdown]
# ## The components of a web page

# %% [markdown]
# When we visit a web page, our web browser makes a GET request to a web server. The server then sends back files that tell our browser how to render the page for us. The files fall into a few main types:
#
# - HTML — contain the main content of the page.
# - CSS — add styling to make the page look nicer.
# - JS — Javascript files add interactivity to web pages.
# - Images — image formats, such as JPG and PNG allow web pages to show pictures.
#
# After our browser receives all the files, it renders the page and displays it to us. There’s a lot that happens behind the scenes to render a page nicely, but we don’t need to worry about most of it when we’re web scraping.

# %% [markdown]
# ### HTML
#
#
# HyperText Markup Language (HTML) is a language that web pages are created in. HTML isn’t a programming language, like Python — instead, it’s a markup language that tells a browser how to layout content.
#
# Let’s take a quick tour through HTML so we know enough to scrape effectively. HTML consists of elements called tags. The most basic tag is the `<html>` tag. This tag tells the web browser that everything inside of it is HTML. We can make a simple HTML document just using this tag:
# ~~~
# <html>
# </html>
# ~~~

# %% [markdown]
# <html>
#
# </html>

# %% [markdown]
# Right inside an html tag, we put two other tags, the head tag, and the body tag. The main content of the web page goes into the body tag. The head tag contains data about the title of the page, and other information that generally isn’t useful in web scraping:
#
# ~~~
# <html>
#     <head>
#     </head>
#     <body>
#     </body>
# </html>
# ~~~

# %% [markdown]
# We’ll now add our first content to the page, in the form of the p tag. The p tag defines a paragraph, and any text inside the tag is shown as a separate paragraph:
# ~~~
# <html>
#     <head>
#     </head>
#     <body>
#           <p>
#              Here's a paragraph of text!
#         </p>
#         <p>
#             Here's a second paragraph of text!
#         </p>
#     </body>
# </html>
# ~~~

# %% [markdown]
# <html>
#     <head>
#     </head>
#     <body>
#           <p>
#             Here's a paragraph of text!
#         </p>
#         <p>
#            Here's a second paragraph of text!
#         </p>
#     </body>
# </html>

# %% [markdown]
# #### HTML tags relationships

# %% [markdown]
# Tags have commonly used names that depend on their position in relation to other tags:
#
# - **child** — a child is a tag inside another tag
# - **parent** — a parent is the tag another tag is inside
# - **sibiling** — a sibiling is a tag that is nested inside the same parent as another tag

# %% [markdown]
# ~~~
# <html>
#
#   <head>
#     <title> I am a Title </title>
#   </head>
#
#   <body>
#     <h1>I am a body </h1>
#     <p>Hello world!</p>
#   </body>
#
# </html>
# ~~~

# %% [markdown]
# From the HTML above you can read:
#
# - `<html>` is the root node
# - `<html>` has no parents
# - `<html>` is the parent of `<head>` and `<body>`
# - `<head>` is the first child of `<html>`
# - `<body>` is the last child of `<html>`
#
# and:
#
# - `<head>` has one child: `<title>`
# - `<title>` has one child (a text node): "I am a title"
# - `<body>` has two children: `<h1>` and` <p>`
# - `<h1>` has one child: "i am a body"
# - `<p>` has one child: "Hello world!"
# - `<h1>` and `<p>` are siblings

# %% [markdown]
# We can also add properties to HTML tags that change their behavior:
#
# ~~~
# <html>
#   <head>
#   </head>
#     <body>
#       <p>
#         Here's a paragraph of text!
#         <a href="https://www.dataquest.io">Learn Data Science Online</a>
#         </p>
#         <p>
#           Here's a second paragraph of text!
#           <a href="https://www.python.org">Python</a>
#         </p>
#     </body>
# </html>
# ~~~

# %% [markdown]
# <html>
#     <head>
#     </head>
#     <body>
#         <p>
#             Here's a paragraph of text!
#             <a href="https://www.dataquest.io">Learn Data Science Online</a>
#         </p>
#         <p>
#             Here's a second paragraph of text!
#             <a href="https://www.python.org">Python</a>        </p>
#     </body></html>

# %% [markdown]
# In the above example, we added two a tags. a tags are links, and tell the browser to render a link to another web page. The href property of the tag determines where the link goes.
#
# a and p are extremely common html tags. Here are a few others:
#
# - *div* — indicates a division, or area, of the page.
# - *b* — bolds any text inside.
# - *i* — italicizes any text inside.
# - *table* — creates a table.
# - *form* — creates an input form.
#
#
# For a full list of tags, look [here](https://developer.mozilla.org/en-US/docs/Web/HTML/Element).

# %% [markdown]
# There are two special properties give HTML elements names, and make them easier to interact with when we’re scraping, **class** and **id** properties.
#
# - One element can have multiple classes, and a class can be shared between elements.
# - Each element can only have one id, and an id can only be used once on a page.
# - Classes and ids are optional, and not all elements will have them.
#
# We can add classes and ids to our example:
#
# ~~~
# <html>
#     <head>
#     </head>
#     <body>
#         <p class="bold-paragraph">
#             Here's a paragraph of text!
#             <a href="https://www.dataquest.io" id="learn-link">Learn Data Science Online</a>
#         </p>
#         <p class="bold-paragraph extra-large">
#             Here's a second paragraph of text!
#             <a href="https://www.python.org" class="extra-large">Python</a>
#         </p>
#     </body>
# </html>
# ~~~

# %% [markdown]
# <html>
#     <head>
#     </head>
#     <body>
#         <p class="bold-paragraph">
#             Here's a paragraph of text!
#             <a href="https://www.dataquest.io" id="learn-link">Learn Data Science Online</a>
#         </p>
#         <p class="bold-paragraph extra-large">
#             Here's a second paragraph of text!
#             <a href="https://www.python.org" class="extra-large">Python</a>
#         </p>
#     </body>
# </html>

# %% [markdown]
# ## Apply this knowledge
#
# Let's go to a webpage and change some of the HTML to see what happens.
#
# - Open up a webpage in Chrome.
# - Right click and 'inspect element.
#
# - Change the text in a tag.
# - Change the class of a tag.
# - Find a tag with an ID and remove it.

# %% [markdown]
# <html>
#  <head>
#   <title>
#    A simple example page
#
#   </title>
#   <h1>a title</h1>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## Webscraping with Python

# %% [markdown]
# ### The requests library
# The first thing we’ll need to do to scrape a web page is to download the page. We can download pages using the Python requests library.

# %%
import requests
import sys
import numpy as np
import time
time.sleep(5)
page = requests.get("http://dataquestio.github.io/web-scraping-pages/simple.html")
page
# Out:
# <Response [200]>

# %% [markdown]
# After running our request, we get a Response object. This object has a status_code property, which indicates if the page was downloaded successfully:

# %%
page.status_code
# Out:
# 200

# %% [markdown]
# We can print out the HTML content of the page using the content property:

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html>\n    <head>\n        <title>A simple example page</title>\n    </head>\n    <body>\n        <p>Here is some simple content for this page.</p>\n    </body>\n</html>'

# %% [markdown]
# ### Parsing a page with BeautifulSoup
#
# We can use the BeautifulSoup library to parse this document, and extract the text from the `<p>` tag.

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <p>
#    Here is some simple content for this page.
#   </p>
#  </body>
# </html>

# %% [markdown]
# As all the tags are nested, we can move through the structure one level at a time. We can first select all the elements at the top level of the page using the `children` property of `soup`.

# %%
list(soup.children)
# Out:
# ['html', '\n', <html>
#  <head>
#  <title>A simple example page</title>
#  </head>
#  <body>
#  <p>Here is some simple content for this page.</p>
#  </body>
#  </html>]

# %% [markdown]
# The above tells us that there are two tags at the top level of the page — the initial `<!DOCTYPE html>` tag, and the `<html>` tag. There is a newline character `(\n)` in the list as well. Let’s see what the type of each element in the list is:

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.NavigableString, bs4.element.Tag]

# %% [markdown]
# The `Tag` object allows us to navigate through an HTML document, and extract other tags and text. You can learn more about the various `BeautifulSoup` objects [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/#kinds-of-objects).
#
# We can now select the html tag and its children by taking the third item in the list:

# %%
html = list(soup.children)[2]
html
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %% [markdown]
# Each item in the list returned by the `children` property is also a `BeautifulSoup` object, so we can also call the `children` method on `html`.
#
# Now, we can find the `children` inside the `html` tag:

# %%
list(html.children)[3]
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %% [markdown]
# As you can see above, there are two tags here, `head`, and `body`. We want to extract the text inside the `p` tag, so we’ll dive into the body:

# %%
body = list(html.children)[3]
body
# Out:
# <body>
# <p>Here is some simple content for this page.</p>
# </body>

# %% [markdown]
# We can now isolate the `p` tag:

# %%
p = list(body.children)[1]
p
# Out:
# <p>Here is some simple content for this page.</p>

# %% [markdown]
# Once we’ve isolated the tag, we can use the `get_text` method to extract all of the text inside the tag:

# %%
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# You can also access the text using the attribute `text`

# %%
###
p.text
###

###
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# ### Finding all instances of a tag at once
#
# If we want to extract a single tag, we can instead use the find_all method, which will find all the instances of a tag on a page.

# %%
soup = BeautifulSoup(page.content, 'html.parser')
soup.find_all('p')
# Out:
# [<p>Here is some simple content for this page.</p>]

# %% [markdown]
# Note that `find_all` returns a list, so we’ll have to loop through, or use list indexing, it to extract text:

# %%
soup.find_all('p')[0].text
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# If you instead only want to find the first instance of a tag, you can use the `find` method, which will return a single `BeautifulSoup` object:

# %%
soup.find('p').text
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# You can also access the tags like an attribute of the soup object by using `p` and then `text`.

# %%
soup.p.text
# Out:
# 'Here is some simple content for this page.'

# %% [markdown]
# ### Searching for tags by class and id
#
#
# We introduced classes and ids earlier, but it probably wasn’t clear why they were useful. Classes and ids are used by CSS to determine which HTML elements to apply certain styles to. We can also use them when scraping to specify specific elements we want to scrape. Let's look at the following page:
#
# ~~~
# <html>
#     <head>
#         <title>A simple example page</title>
#     </head>
#     <body>
#         <div>
#             <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>
#             <p class="inner-text">
#                 Second paragraph.
#             </p>
#         </div>
#         <p class="outer-text first-item" id="second">
#             <b>
#                 First outer paragraph.
#             </b>
#         </p>
#         <p class="outer-text">
#             <b>
#                 Second outer paragraph.
#             </b>
#         </p>
#     </body>
# </html>
# ~~~

# %%
page = requests.get("http://dataquestio.github.io/web-scraping-pages/ids_and_classes.html")
soup = BeautifulSoup(page.content, 'html.parser')
soup
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <div>
# <p class="inner-text first-item" id="first">
#                 First paragraph.
#             </p>
# <p class="inner-text">
#                 Second paragraph.
#             </p>
# </div>
# <p class="outer-text first-item" id="second">
# <b>
#                 First outer paragraph.
#             </b>
# </p>
# <p class="outer-text">
# <b>
#                 Second outer paragraph.
#             </b>
# </p>
# </body>
# </html>

# %%
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    A simple example page
#   </title>
#  </head>
#  <body>
#   <div>
#    <p class="inner-text first-item" id="first">
#     First paragraph.
#    </p>
#    <p class="inner-text">
#     Second paragraph.
#    </p>
#   </div>
#   <p class="outer-text first-item" id="second">
#    <b>
#     First outer paragraph.
#    </b>
#   </p>
#   <p class="outer-text">
#    <b>
#     Second outer paragraph.
#    </b>
#   </p>
#  </body>
# </html>

# %% [markdown]
# Now, we can use the `find_all` method to search for items by class or by id. In the below example, we’ll search for any `p` tag that has the class `outer-text`:

# %%
soup.find_all('p', class_='outer-text')
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %% [markdown]
# In the below example, we’ll look for any tag that has the class `outer-text`:

# %%
soup.find_all(class_="outer-text")
# Out:
# [<p class="outer-text first-item" id="second">
#  <b>
#                  First outer paragraph.
#              </b>
#  </p>, <p class="outer-text">
#  <b>
#                  Second outer paragraph.
#              </b>
#  </p>]

# %% [markdown]
# We can also search for elements by `id`:

# %%
soup.find_all(id="first")
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>]

# %% [markdown]
# ### Using CSS Selectors
#
#
# You can also search for items using CSS selectors. These selectors are how the CSS language allows developers to specify HTML tags to style. Here are some examples:
#
# - *p a* — finds all a tags inside of a p tag.
# - *body p a* — finds all a tags inside of a p tag inside of a body tag.
# - *html body* — finds all body tags inside of an html tag.
# - *p.outer-text* — finds all p tags with a class of outer-text.
# - *p#first* — finds all p tags with an id of first.
# - *body p.outer-text* — finds any p tags with a class of outer-text inside of a body tag.

# %% [markdown]
# `BeautifulSoup` objects support searching a page via CSS selectors using the `select` method. We can use CSS selectors to find all the `p` tags in our page that are inside of a `div` like this:

# %%
soup.select("div p")
# Out:
# [<p class="inner-text first-item" id="first">
#                  First paragraph.
#              </p>, <p class="inner-text">
#                  Second paragraph.
#              </p>]

# %% [markdown]
# Note that the `select` method above returns a list of `BeautifulSoup` objects, just like `find` and `find_all`.

# %% [markdown]
# ## Example 1: Downloading weather data

# %% [markdown]
# We now know enough to proceed with extracting information about the local weather from the National Weather Service website. The first step is to find the page we want to scrape. We’ll extract weather information about downtown San Francisco from this [page](https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.XJJFuhNKhTY).

# %% [markdown]
# We can then scroll up in the elements panel to find the “outermost” element that contains all of the text that corresponds to the extended forecasts. In this case, it’s a `div` tag with the id `seven-day-forecas`t:

# %% [markdown]
# We now know enough to download the page and start parsing it. In the below code, we:
#
# 1. Download the web page containing the forecast.
# 2. Create a `BeautifulSoup` class to parse the page.
# 3. Find the `div` with id `seven-day-forecast`, and assign to `seven_day`
# 4. Inside `seven_day`, find each individual forecast item.
# 5. Extract and print the first forecast item.

# %%
#your code here

page = requests.get("http://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168")
soup = BeautifulSoup(page.content, 'html.parser')
seven_day = soup.find(id="seven-day-forecast")

forecast_items = seven_day.find_all(class_="tombstone-container")
tonight = forecast_items[0]
print(tonight.prettify())
# Out:
# <div class="tombstone-container">
#  <p class="period-name">
#   Today
#   <br/>
#   <br/>
#  </p>
#  <p>
#   <img alt="Today: Sunny, with a high near 70. West wind 6 to 15 mph, with gusts as high as 21 mph. " class="forecast-icon" src="newimages/medium/few.png" title="Today: Sunny, with a high near 70. West wind 6 to 15 mph, with gusts as high as 21 mph. "/>
#  </p>
#  <p class="short-desc">
#   Sunny
#  </p>
#  <p class="temp temp-high">
#   High: 70 °F
#  </p>
# </div>

# %%
tonight.find('p').text
# Out:
# 'Today'

# %%
# want to get temperature
tonight.find("p", class_ = "temp temp-high").text
# Out:
# 'High: 70 °F'

# %%
tonight.find('p', class_ = "period-name").text
# Out:
# 'Today'

# %%
type(seven_day)
# Out:
# bs4.element.Tag

# %%
len(forecast_items)
# Out:
# 9

# %% [markdown]
# ### Extracting information from the page
# As you can see, inside the forecast item `tonight` is all the information we want. There are `4` pieces of information we can extract:
#
# - The name of the forecast item — in this case, **Tonight**.
# - The description of the conditions — this is stored in the `title` property of `img`.
# - A short description of the conditions — in this case, **Mostly Cloudy**.
# - The temperature low — in this case, **49 degrees**.
#
# We’ll extract the name of the forecast item, the short description, and the temperature first, since they’re all similar:

# %% [markdown]
# Now, we can extract the `title` attribute from the `img` tag. To do this, we just treat the `BeautifulSoup` object like a dictionary, and pass in the attribute we want as a key:

# %% [markdown]
# Now that we know how to extract each individual piece of information, we can combine our knowledge with css selectors and list comprehensions to extract everything at once.
#
# In the below code, we:
#
# - Select all items with the class period-name inside an item with the class tombstone-container in seven_day.
# - Use a list comprehension to call the get_text method on each BeautifulSoup object.

# %%
period_tags = seven_day.select(".tombstone-container .period-name")
periods = [pt.get_text() for pt in period_tags]
periods
# Out:
# ['Today',
#  'Tonight',
#  'Saturday',
#  'SaturdayNight',
#  'Sunday',
#  'SundayNight',
#  'MemorialDay',
#  'MondayNight',
#  'Tuesday']

# %%
# in css, when selecting by class. you can do .class .class to indicate different hierarchy
# when they are on the same hierarchy, i can do .class.class

# %% [markdown]
# As you can see above, our technique gets us each of the period names, in order. Now you can apply the same technique to get the other 3 fields:

# %%
#your code here
short_descs = [sd.get_text() for sd in seven_day.select(".tombstone-container .short-desc")]
temps = [t.get_text() for t in seven_day.select(".tombstone-container .temp")]
descs = [d["title"] for d in seven_day.select(".tombstone-container img")]

print(short_descs)
print(temps)
print(descs)
# Out:
# ['Sunny', 'Clear', 'Sunny', 'Mostly Clear', 'Sunny', 'Mostly Clear', 'Sunny', 'Mostly Clear', 'Sunny']
# ['High: 70 °F', 'Low: 56 °F', 'High: 72 °F', 'Low: 55 °F', 'High: 75 °F', 'Low: 57 °F', 'High: 78 °F', 'Low: 58 °F', 'High: 81 °F']
# ['Today: Sunny, with a high near 70. West wind 6 to 15 mph, with gusts as high as 21 mph. ', 'Tonight: Clear, with a low around 56. West wind 5 to 14 mph, with gusts as high as 18 mph. ', 'Saturday: Sunny, with a high near 72. West wind 5 to 10 mph increasing to 11 to 16 mph in the afternoon. Winds could gust as high as 22 mph. ', 'Saturday Night: Mostly clear, with a low around 55. West southwest wind 5 to 15 mph, with gusts as high as 21 mph. ', 'Sunday: Sunny, with a high near 75. Light south wind becoming west southwest 8 to 13 mph in the afternoon. Winds could gust as high as 18 mph. ', 'Sunday Night: Mostly clear, with a low around 57.', 'Memorial Day: Sunny, with a high near 78.', 'Monday Night: Mostly clear, with a low around 58.', 'Tuesday: Sunny, with a high near 81.']

# %%
seven_day.select(".tombstone-container img")[0]['title']
# Out:
# 'Today: Sunny, with a high near 70. West wind 6 to 15 mph, with gusts as high as 21 mph. '

# %% [markdown]
# ### Combining our data into a Pandas Dataframe
#
# We can now combine the data into a Pandas DataFrame and analyze it.
#
# In order to do this, we’ll call the DataFrame class, and pass in each list of items that we have. We pass them in as part of a dictionary. Each dictionary key will become a column in the DataFrame, and each list will become the values in the column:

# %%
import pandas as pd
weather = pd.DataFrame({
        "period": periods,
         "short_desc": short_descs,
         "temp": temps,
         "desc":descs
    })
weather
# Out:
#           period    short_desc         temp  \
# 0          Today         Sunny  High: 70 °F
# 1        Tonight         Clear   Low: 56 °F
# 2       Saturday         Sunny  High: 72 °F
# 3  SaturdayNight  Mostly Clear   Low: 55 °F
# 4         Sunday         Sunny  High: 75 °F
# 5    SundayNight  Mostly Clear   Low: 57 °F
# 6    MemorialDay         Sunny  High: 78 °F
# 7    MondayNight  Mostly Clear   Low: 58 °F
# 8        Tuesday         Sunny  High: 81 °F
#
#                                                 desc
# 0  Today: Sunny, with a high near 70. West wind 6...
# 1  Tonight: Clear, with a low around 56. West win...
# 2  Saturday: Sunny, with a high near 72. West win...
# 3  Saturday Night: Mostly clear, with a low aroun...
# 4  Sunday: Sunny, with a high near 75. Light sout...
# 5  Sunday Night: Mostly clear, with a low around 57.
# 6          Memorial Day: Sunny, with a high near 78.
# 7  Monday Night: Mostly clear, with a low around 58.
# 8               Tuesday: Sunny, with a high near 81.

# %% [markdown]
# We can now do some analysis on the data. For example, we can use a regular expression and the Series.str.extract method to pull out the numeric temperature values:

# %%
temp_nums = weather["temp"].str.extract("(\d+)", expand=False)
temp_nums
# Out:
# 0    70
# 1    56
# 2    72
# 3    55
# 4    75
# 5    57
# 6    78
# 7    58
# 8    81
# Name: temp, dtype: object

# %%
temp_nums = weather["temp"].str.extract("(?P<temp_num>\d+)", expand=False)
weather["temp_num"] = temp_nums.astype('int')
temp_nums
# Out:
# 0    70
# 1    56
# 2    72
# 3    55
# 4    75
# 5    57
# 6    78
# 7    58
# 8    81
# Name: temp_num, dtype: object

# %%
weather
# Out:
#           period    short_desc         temp  \
# 0          Today         Sunny  High: 70 °F
# 1        Tonight         Clear   Low: 56 °F
# 2       Saturday         Sunny  High: 72 °F
# 3  SaturdayNight  Mostly Clear   Low: 55 °F
# 4         Sunday         Sunny  High: 75 °F
# 5    SundayNight  Mostly Clear   Low: 57 °F
# 6    MemorialDay         Sunny  High: 78 °F
# 7    MondayNight  Mostly Clear   Low: 58 °F
# 8        Tuesday         Sunny  High: 81 °F
#
#                                                 desc  temp_num
# 0  Today: Sunny, with a high near 70. West wind 6...        70
# 1  Tonight: Clear, with a low around 56. West win...        56
# 2  Saturday: Sunny, with a high near 72. West win...        72
# 3  Saturday Night: Mostly clear, with a low aroun...        55
# 4  Sunday: Sunny, with a high near 75. Light sout...        75
# 5  Sunday Night: Mostly clear, with a low around 57.        57
# 6          Memorial Day: Sunny, with a high near 78.        78
# 7  Monday Night: Mostly clear, with a low around 58.        58
# 8               Tuesday: Sunny, with a high near 81.        81

# %% [markdown]
# We could then find the mean of all the high and low temperatures:

# %%
weather["temp_num"].mean()
# Out:
# 66.88888888888889

# %% [markdown]
# We could also only select the rows that happen at night:

# %%
is_night = weather["temp"].str.contains("Low")
weather["is_night"] = is_night
is_night
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5     True
# 6    False
# 7     True
# 8    False
# Name: temp, dtype: bool

# %%
weather[is_night]
# Out:
#           period    short_desc        temp  \
# 1        Tonight         Clear  Low: 56 °F
# 3  SaturdayNight  Mostly Clear  Low: 55 °F
# 5    SundayNight  Mostly Clear  Low: 57 °F
# 7    MondayNight  Mostly Clear  Low: 58 °F
#
#                                                 desc  temp_num  is_night
# 1  Tonight: Clear, with a low around 56. West win...        56      True
# 3  Saturday Night: Mostly clear, with a low aroun...        55      True
# 5  Sunday Night: Mostly clear, with a low around 57.        57      True
# 7  Monday Night: Mostly clear, with a low around 58.        58      True
